# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('player_embedding.csv')
vectors = df.iloc[:,4:]
vectors
# Out:
#         feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0        3.265667   0.757148   1.709361        0.0   1.870791   0.000000
# 1        3.758625   1.209742   1.564240        0.0   0.474581   0.460083
# 2        2.898894   1.266350   1.875545        0.0   1.957869   0.040286
# 3        3.622704   1.384349   1.968731        0.0   0.689646   0.611457
# 4        2.284001   1.387072   2.395956        0.0   1.186806   0.054275
# ...           ...        ...        ...        ...        ...        ...
# 126283   0.463187   0.528406   0.896661        0.0   0.989502   1.371228
# 126284   0.459426   0.739470   0.860212        0.0   0.998605   1.291639
# 126285   0.583554   0.534359   0.883899        0.0   1.025931   1.386753
# 126286   0.524298   0.523198   0.106561        0.0   1.139934   1.555437
# 126287   0.477626   0.485325   0.789953        0.0   0.968748   1.572309
#
#         feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  \
# ...

# %%
labels = pd.read_csv('Cleaned_Data/player_cleaned_encoded.csv').iloc[:,2:5]
labels
# Out:
#                 short_name player_positions  overall
# 0                 L. Messi               CF       93
# 1        Cristiano Ronaldo           LW, LM       92
# 2                A. Robben       RM, LM, RW       90
# 3           Z. Ibrahimović               ST       90
# 4                  Iniesta           CM, LW       89
# ...                    ...              ...      ...
# 126283           Song Defu              CDM       47
# 126284           C. Porter               CM       47
# 126285            N. Logue               CM       47
# 126286           L. Rudden               ST       47
# 126287  E. Lalchhanchhuaha              CAM       47
#
# [126288 rows x 3 columns]

# %%
vectors.to_csv('player_vectors.tsv', header=False, sep='\t', encoding='utf-8', index=False)

# %%
labels.to_csv('player_tsv_label.tsv', sep='\t', encoding='utf-8', index=False)

# %%
team_vectors = pd.read_csv('team_embedding.csv').iloc[:,2:-3]
team_vectors.to_csv('team_vectors.tsv', header=False, sep='\t', encoding='utf-8', index=False)

# %%
team_labels = pd.read_csv('team_embedding.csv')[['team','season']]
team_labels.to_csv('team_tsv_label.tsv', sep='\t', encoding='utf-8', index=False)
